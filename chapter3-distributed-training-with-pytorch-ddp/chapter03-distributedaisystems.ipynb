# %%
# !git clone https://github.com/PacktPublishing/Distributed-AI-Systems
# Out:
# Cloning into 'Distributed-AI-Systems'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (358/358), done.
# remote: Compressing objects: 100% (253/253), done.
# remote: Total 358 (delta 81), reused 344 (delta 71), pack-reused 0 (from 0)
# Receiving objects: 100% (358/358), 1.63 MiB | 10.65 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
# !CUDA_VISIBLE_DEVICES=0,1 torchrun --nproc_per_node=2 /kaggle/working/Distributed-AI-Systems/chapter3-distributed-training-with-pytorch-ddp/code/profile_ddp.py
# Out:
# W0819 10:57:26.338000 54 torch/distributed/run.py:852]
# W0819 10:57:26.338000 54 torch/distributed/run.py:852] *****************************************
# W0819 10:57:26.338000 54 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0819 10:57:26.338000 54 torch/distributed/run.py:852] *****************************************
# /usr/local/lib/python3.12/dist-packages/torch/profiler/profiler.py:217: UserWarning: Warning: Profiler clears events at the end of each cycle.Only events from the current cycle will be reported.To keep events across cycles, set acc_events=True.
#   _warn_once(
# ...

# %%
# !torchrun --nproc_per_node=2 /kaggle/working/Distributed-AI-Systems/chapter3-distributed-training-with-pytorch-ddp/code/profile_ddp_overlap.py
# Out:
# W0819 10:57:40.126000 93 torch/distributed/run.py:852]
# W0819 10:57:40.126000 93 torch/distributed/run.py:852] *****************************************
# W0819 10:57:40.126000 93 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0819 10:57:40.126000 93 torch/distributed/run.py:852] *****************************************
# /usr/local/lib/python3.12/dist-packages/torch/profiler/profiler.py:217: UserWarning: Warning: Profiler clears events at the end of each cycle.Only events from the current cycle will be reported.To keep events across cycles, set acc_events=True.
#   _warn_once(
# ...
